# %%
import pandas as pd

# %% [markdown]
# # 1. Open the categoricals variable we created before.

# %%
data = pd.read_csv('categorical.csv')

# %%
data
# Out:
#      Customer       State Response  Coverage Education EmploymentStatus  \
# 0          BU  Washington       No     Basic  Bachelor         Employed
# 1          QZ     Arizona       No  Extended  Bachelor       Unemployed
# 2          AI      Nevada       No   Premium  Bachelor         Employed
# 3          WW  California       No     Basic  Bachelor       Unemployed
# 4          HB  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129       LA  California       No     Basic  Bachelor         Employed
# 9130       PK  California      Yes  Extended   College         Employed
# 9131       TD  California       No  Extended  Bachelor       Unemployed
# 9132       UP  California       No  Extended   College         Employed
# 9133        Y  California       No  Extended   College       Unemployed
#
#      Gender Location Code Marital Status     Policy Type        Policy  \
# ...

# %% [markdown]
# # 2. Plot all the categorical variables with the proper plot. What can you see?

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as pamella

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Response', 'Coverage', 'Education',
#        'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status',
#        'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel',
#        'Vehicle Class', 'Vehicle Size', 'customer_id', 'Year'],
#       dtype='object')

# %%
# Define the columns to plot
cols_to_plot = ['Customer', 'State', 'Response', 'Coverage', 'Education', 'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Create the figure and axes
fig, axs = pamella.subplots(5, 3, figsize=(25, 30))

# Loop through the columns to plot
for i, col in enumerate(cols_to_plot):

    # Select the appropriate axes
    ax = axs[i//3, i%3]

    # Create a countplot
    sns.countplot(x=col, data=data, ax=ax)

    # Set the axis label and tick label font size
    ax.set_xlabel(col, fontsize=14)
    ax.tick_params(labelsize=12)
    
    # Rotate x-axis tick labels to vertical and y-axis tick labels to horizontal
    ax.tick_params(axis='x', rotation=90)
    ax.tick_params(axis='y', rotation=0)

# Add a title to the figure
fig.suptitle('Distribution of Categorical Variables', fontsize=20)

# Adjust the spacing between subplots
fig.tight_layout(pad=5)

# Show the plot
pamella.show()

# %%
<p>the customer plot doesn't show nothing<\p>
<p>we can see that the most costumer are from california and oregon<\p>
<p>we can see that the most costumer didn't respond<\p>
<p>we can see that the most costumer are employed<\p>
<p>we can see that the most costumer preffer medsize and foor door vehicles<\p>

# %% [markdown]
# # 3. There might be some columns that seem to be redundant, check their values to be sure. What should we do with them?

# %% [markdown]
# Policy type and policy seeam to be redundant

# %%
data["Policy Type"].equals(data["Policy"])
# Out:
# False

# %% [markdown]
# Although the data displayed in the two columns is not exactly the same, the data gives redundant information so I will delete the Policy column

# %%
data
# Out:
#      Customer       State Response  Coverage Education EmploymentStatus  \
# 0          BU  Washington       No     Basic  Bachelor         Employed
# 1          QZ     Arizona       No  Extended  Bachelor       Unemployed
# 2          AI      Nevada       No   Premium  Bachelor         Employed
# 3          WW  California       No     Basic  Bachelor       Unemployed
# 4          HB  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129       LA  California       No     Basic  Bachelor         Employed
# 9130       PK  California      Yes  Extended   College         Employed
# 9131       TD  California       No  Extended  Bachelor       Unemployed
# 9132       UP  California       No  Extended   College         Employed
# 9133        Y  California       No  Extended   College       Unemployed
#
#      Gender Location Code Marital Status     Policy Type        Policy  \
# ...

# %%
data_df_clean = data.drop('Policy', axis=1, inplace=False)

# %%
data_df_clean
# Out:
#      Customer       State Response  Coverage Education EmploymentStatus  \
# 0          BU  Washington       No     Basic  Bachelor         Employed
# 1          QZ     Arizona       No  Extended  Bachelor       Unemployed
# 2          AI      Nevada       No   Premium  Bachelor         Employed
# 3          WW  California       No     Basic  Bachelor       Unemployed
# 4          HB  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129       LA  California       No     Basic  Bachelor         Employed
# 9130       PK  California      Yes  Extended   College         Employed
# 9131       TD  California       No  Extended  Bachelor       Unemployed
# 9132       UP  California       No  Extended   College         Employed
# 9133        Y  California       No  Extended   College       Unemployed
#
#      Gender Location Code Marital Status     Policy Type Renew Offer Type  \
# ...

# %% [markdown]
# # 4. Plot time variable. Can you extract something from it?

# %% [markdown]
# Since we droped the Effective to Date column in the previous lab I will merge it back to this dataframe

# %%
data_4 = pd.read_csv('categorical_effective.csv')

# %%
data_4
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0     BU79786  Washington       No     Basic  Bachelor        2011-02-24
# 1     QZ44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2     AI49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3     WW63253  California       No     Basic  Bachelor        2011-01-20
# 4     HB64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor        2011-02-10
# 9130  PK87824  California      Yes  Extended   College        2011-02-12
# 9131  TD14365  California       No  Extended  Bachelor        2011-02-06
# 9132  UP19263  California       No  Extended   College        2011-02-03
# 9133  Y167826  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
data_4.dtypes
# Out:
# Customer             object
# State                object
# Response             object
# Coverage             object
# Education            object
# Effective To Date    object
# EmploymentStatus     object
# Gender               object
# Location Code        object
# Marital Status       object
# Policy Type          object
# Policy               object
# Renew Offer Type     object
# Sales Channel        object
# Vehicle Class        object
# Vehicle Size         object
# dtype: object

# %%
data_4['Effective To Date'] = pd.to_datetime(data_4['Effective To Date'], format='%Y-%m-%d')

# %%
data_4.dtypes
# Out:
# Customer                     object
# State                        object
# Response                     object
# Coverage                     object
# Education                    object
# Effective To Date    datetime64[ns]
# EmploymentStatus             object
# Gender                       object
# Location Code                object
# Marital Status               object
# Policy Type                  object
# Policy                       object
# Renew Offer Type             object
# Sales Channel                object
# Vehicle Class                object
# Vehicle Size                 object
# dtype: object

# %%
# Select the 'Effective To Date' column from data_4
effective_to_date = data_4['Effective To Date']

# Merge the 'Effective To Date' column with data_df_clean
merged_df = pd.concat([data_df_clean, effective_to_date], axis=1)

# Print the merged dataframe
merged_df
# Out:
#      Customer       State Response  Coverage Education EmploymentStatus  \
# 0          BU  Washington       No     Basic  Bachelor         Employed
# 1          QZ     Arizona       No  Extended  Bachelor       Unemployed
# 2          AI      Nevada       No   Premium  Bachelor         Employed
# 3          WW  California       No     Basic  Bachelor       Unemployed
# 4          HB  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129       LA  California       No     Basic  Bachelor         Employed
# 9130       PK  California      Yes  Extended   College         Employed
# 9131       TD  California       No  Extended  Bachelor       Unemployed
# 9132       UP  California       No  Extended   College         Employed
# 9133        Y  California       No  Extended   College       Unemployed
#
#      Gender Location Code Marital Status     Policy Type Renew Offer Type  \
# ...

# %%
# create dataframe
df = data_4['Effective To Date'].value_counts().sort_index().reset_index()

# rename columns
df.columns = ['Effective To Date', 'value']

# Rotate x-axis tick labels to vertical and y-axis tick labels to horizontal
ax = plt.gca()
ax.tick_params(axis='x', rotation=90)
ax.tick_params(axis='y', rotation=0)

# create plot
plt.plot(df['Effective To Date'], df['value'])
plt.title('Ploting Effective To Date')
plt.xlabel('Effective To Date')
plt.ylabel('Values')
plt.show()

# %% [markdown]
# There are no major conclusions that can be drawn from this plot.

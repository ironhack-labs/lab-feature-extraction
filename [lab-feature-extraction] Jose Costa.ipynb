# %%
#1. Open the categoricals variable we created before.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

categorical=pd.read_csv("categorical.csv",index_col=0)
categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status        policy renew_offer_type  \
# ...

# %%
#2. Plot all the categorical variables with the proper plot. What can you see?

for column in categorical.columns:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    categorical[column].value_counts().plot.bar(ax=ax1)
    ax1.set_title(column)

    categorical[column].value_counts().plot.pie(ax=ax2, autopct="%1.1f%%")
    ax2.set_title(column)

    fig.tight_layout()
    plt.show()

# %% [markdown]
# It is visible that in some columns, We could join some values into "Other" be more comparable to others, and decrease the number of variables. E.g., in policy joining all the "Special", employment status be "employed", "unemployed" and "others", and so on. In this case let's leave those as they are, as they might be important.
#
# PS: sowy for the Pie charts, it was good for my analysis above.

# %%
#4. Plot time variable. Can you extract something from it?

# %% [markdown]
# We can split into months and years, for example, and analyse as categorical.

# %%
categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status        policy renew_offer_type  \
# ...

# %%
categorical["effective_to_date"] = pd.to_datetime(categorical["effective_to_date"])
categorical["effective_year"] = categorical["effective_to_date"].dt.year
categorical["effective_month"] = categorical["effective_to_date"].dt.month
categorical["effective_month"] = categorical["effective_to_date"].dt.strftime("%B") # Converts month number to month name

categorical
# Out:
#            state response  coverage education employmentstatus gender  \
# 0     Washington       No     Basic  Bachelor         Employed      F
# 1        Arizona       No  Extended  Bachelor       Unemployed      F
# 2         Nevada       No   Premium  Bachelor         Employed      F
# 3     California       No     Basic  Bachelor       Unemployed      M
# 4     Washington       No     Basic  Bachelor         Employed      M
# ...          ...      ...       ...       ...              ...    ...
# 9129  California       No     Basic  Bachelor         Employed      M
# 9130  California      Yes  Extended   College         Employed      F
# 9131  California       No  Extended  Bachelor       Unemployed      M
# 9132  California       No  Extended   College         Employed      M
# 9133  California       No  Extended   College       Unemployed      M
#
#      location_code marital_status        policy renew_offer_type  \
# ...

# %%
categorical.drop(columns=["effective_to_date"],axis=1,inplace=True)

# %%
categorical.dtypes
# Out:
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# effective_year       int64
# effective_month     object
# dtype: object

# %%
categorical["effective_year"] = categorical["effective_year"].astype(str)
categorical.dtypes
# Out:
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# effective_year      object
# effective_month     object
# dtype: object

# %%
categorical.to_csv("categorical.csv")
